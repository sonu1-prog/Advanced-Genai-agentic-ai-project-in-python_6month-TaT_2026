# %% [markdown]
# string

# %%
welcome to nareshit & request everyone please subscribe narshit youtube, instagaram
# Out:
#   Cell In[1], line 1
#     welcome to nareshit & request everyone please subscribe narshit youtube, instagaram
#             ^
# SyntaxError: invalid syntax

# %%
'welcome to nareshit & request everyone please subscribe narshit youtube, instagaram'
# Out:
# 'welcome to nareshit & request everyone please subscribe narshit youtube, instagaram'

# %%
'welcome to nareshit
request everyone please
subscribe nareshit youtube,instagram'
# Out:
#   Cell In[3], line 1
#     'welcome to nareshit
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
''welcome to nareshit
request everyone please
subscribe nareshit youtube,instagram''
# Out:
#   Cell In[4], line 1
#     ''welcome to nareshit
#       ^
# SyntaxError: invalid syntax

# %%
'''welcome to nareshit
request everyone please
subscribe nareshit youtube,instagram'''
# Out:
# 'welcome to nareshit\nrequest everyone please\nsubscribe nareshit youtube,instagram'

# %%
s='python'
s
# Out:
# 'python'

# %%
s1='welcome'
s1
# Out:
# 'welcome'

# %%
s1[3]
# Out:
# 'c'

# %%
s1[9]
# Out:
# ----------------------------------------------------------------
# IndexError                     Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 s1[9]
#
# IndexError: string index out of range

# %%
s1
# Out:
# 'welcome'

# %%
s1[-5]
# Out:
# 'l'

# %%
s1
# Out:
# 'welcome'

# %%
len(s1)
# Out:
# 7

# %%
s1[6]
# Out:
# 'e'

# %%
s1
# Out:
# 'welcome'

# %%
s1[1:4]
# Out:
# 'elc'

# %%
s1
# Out:
# 'welcome'

# %%
s2='nareshtechnology'
s2
# Out:
# 'nareshtechnology'
