# %% [markdown]
# variables_name=value

# %%
age=25
print(age)
# Out:
# 25

# %%
name="sonali"
print(name)
# Out:
# sonali

# %%
price=20.00
print(price)
# Out:
# 20.0

# %%
is_active=True
print(is_active)
# Out:
# True

# %% [markdown]
# sorting and printing a value

# %%
x=10
print(x)
# Out:
# 10

# %% [markdown]
# using variables in expressions

# %%
a=10
b=5
result=a+b
print(result)
# Out:
# 15

# %% [markdown]
# changing the value of a variable

# %%
score=50
print(score)
# Out:
# 50

# %%
score=200
print(score)
# Out:
# 200

# %% [markdown]
# Concatenating Strings

# %%
#assigning value to variables
first_name="Tippana"
last_name="Sonali"
full_name=first_name+" "+last_name
print(full_name)
# Out:
# Tippana Sonali

# %% [markdown]
# Using variables in a calculation

# %%
length=10
width=5
area=length*width
print(area)
# Out:
# 50

# %% [markdown]
# Reassigning values to variables

# %%
x=10
print(x)
x=20
print(x)
