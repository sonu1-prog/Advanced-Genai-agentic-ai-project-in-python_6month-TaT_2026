# %% [markdown]
# python operator

# %% [markdown]
# Arithmetic operator

# %%
x1,y1=10,5

# %%
x1+y1
# Out:
# 15

# %%
x1-y1
# Out:
# 5

# %%
x1*y1
# Out:
# 50

# %%
x1/y1
# Out:
# 2.0

# %%
x1//y1
# Out:
# 2

# %%
x1%y1
# Out:
# 0

# %%
2*3
# Out:
# 6

# %%
2**3
# Out:
# 8

# %% [markdown]
# Assignment operator

# %%
x=2

# %%
x=x+2
x
# Out:
# 4

# %%
x+=2
x
# Out:
# 8

# %%
x+=2
x
# Out:
# 10

# %%
x*=2
x
# Out:
# 40

# %%
x*=2
x
# Out:
# 80

# %%
x* =2
x
# Out:
#   Cell In[20], line 1
#     x* =2
#        ^
# SyntaxError: invalid syntax

# %%
x *=2
x
# Out:
# 160

# %%
x/=2
x
# Out:
# 20.0

# %%
x//=2
x
# Out:
# 10.0

# %% [markdown]
# unary operator

# %%
n=7
n
# Out:
# 7

# %%
m=-n
m
# Out:
# -7

# %%
-n
# Out:
# -7

# %% [markdown]
# Relational operator

# %%
a=5
b=6

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a=b

# %%
a==b
# Out:
# True

# %%
c=8
d=10

# %%
c==d
# Out:
# False

# %%
c=d

# %%
print(c)
print(d)
# Out:
# 10
# 10

# %%
c==d
# Out:
# True

# %%
c!=d
# Out:
# False

# %%
c>d
# Out:
# False

# %%
c>=d
# Out:
# True

# %% [markdown]
# Logical table

# %%
a=10
b=15

# %%
a<12 and b<20
# Out:
# True

# %%
a<12 or b<20
# Out:
# True

# %%
a<12 and b<5
# Out:
# False

# %%
x=True
x
# Out:
# True

# %%
not x
# Out:
# False

# %%
-True
# Out:
# -1

# %%
-False
# Out:
# 0

# %%
15+3*5-2
# Out:
# 28

# %%
10+5*(8-1)
# Out:
# 45

# %%
print(10)
print(10,20)
# Out:
# 10
# 10 20

# %%
print('python')
print(10,20,'python')
# Out:
# python
# 10 20 python

# %%
num1=20
num2=30
add=num1+num2
print(add)
# Out:
# 50
