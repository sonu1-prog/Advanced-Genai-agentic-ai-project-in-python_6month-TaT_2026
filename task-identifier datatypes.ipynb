# %% [markdown]
# python Tutorial

# %%
import sys
import keyword
import operator
from datatime import datatime
import os

# %% [markdown]
# keywords

# %% [markdown]
# keywords are the reserved words im python and cannot be used as a identifier

# %%
print(keyword.kwlist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(keyword.kwlist)
#
# NameError: name 'keyword' is not defined

# %%
print(keyword.kwlist)  # list all python keywords
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(keyword.kwlist)  # list all python keywords
#
# NameError: name 'keyword' is not defined

# %%
print(keywords.kwlist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(keywords.kwlist)
#
# NameError: name 'keywords' is not defined

# %%
print(keyword.kwlist)  # list of python keywords
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(keyword.kwlist)  # list of python keywords
#
# NameError: name 'keyword' is not defined

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# identifiers

# %% [markdown]
# An identifier is a name given to entities like class, functions, variables, etc. It helps to differentiate
# one entity from another.

# %%
1var = 10
# Out:
#   Cell In[8], line 1
#     1var = 10
#     ^
# SyntaxError: invalid decimal literal

# %%
val2@ = 35
# Out:
#   Cell In[9], line 1
#     val2@ = 35
#           ^
# SyntaxError: invalid syntax

# %%
import = 125
# Out:
#   Cell In[10], line 1
#     import = 125
#            ^
# SyntaxError: invalid syntax

# %%
""" 
Correct way of defining an identifier 
(Identifiers can be a combination of letters in lowercase (a to z) or uppercase 
""" 
val2 = 10

# %%
val_=99

# %% [markdown]
# Comments in Python

# %%
# Single line comment 
val1 = 10

# %%
# Multiple 
# line 
# comment 
val1 = 10

# %%
"""
# Multiple 
# line 
# comment 
"""
val1 = 10

# %% [markdown]
# Statements

# %% [markdown]
# Instructions that a Python interpreter can execute.

# %%
p = 20  
q = 20  
r = q  
p , type(p), hex(id(p))
# Out:
# (20, int, '0x7ffc8489a608')

# %%
q , type(q), hex(id(q))
# Out:
# (20, int, '0x7ffc8489a608')

# %%
 
r , type(r), hex(id(r))
# Out:
# (20, int, '0x7ffc8489a608')

# %%
 
p = 20 
p = p + 10 # Variable Overwriting 
p
# Out:
# 30

# %% [markdown]
# Variable Assigment

# %%
intvar = 10 # Integer variable 
floatvar = 2.57 # Float Variable 
strvar = "Python Language" # String variable 
print(intvar) 
print(floatvar) 
print(strvar)
# Out:
# 10
# 2.57
# Python Language

# %% [markdown]
# Multiple Assignments

# %%
intvar , floatvar , strvar = 10,2.57,"Python Language" # Using commas to separat 
print(intvar) 
print(floatvar) 
print(strvar)
# Out:
# 10
# 2.57
# Python Language

# %%
p1 = p2 = p3 = p4 = 44 # All variables pointing to same value 
print(p1,p2,p3,p4)
# Out:
# 44 44 44 44

# %% [markdown]
# Data Types
# Numeric

# %%
val1 = 10 # Integer data type 
print(val1) 
print(type(val1)) # type of object 
print(sys.getsizeof(val1)) # size of integer object in bytes 
print(val1, " is Integer?", isinstance(val1, int))
# Out:
# 10
# <class 'int'>
# 28
# 10  is Integer? True

# %%
val2 = 92.78 # Float data type 
print(val2) 
print(type(val2)) # type of object 
print(sys.getsizeof(val2)) # size of float object in bytes 
print(val2, " is float?", isinstance(val2, float))
# Out:
# 92.78
# <class 'float'>
# 24
# 92.78  is float? True

# %%
val3 = 25 + 10j # Complex data type 
print(val3) 
print(type(val3)) # type of object 
print(sys.getsizeof(val3)) # size of float object in bytes 
print(val3, " is complex?", isinstance(val3, complex))
# Out:
# (25+10j)
# <class 'complex'>
# 32
# (25+10j)  is complex? True

# %%
sys.getsizeof(int())
# Out:
# 28

# %%
sys.getsizeof(float())
# Out:
# 24

# %%
sys.getsizeof(complex())
# Out:
# 32

# %%
bool1 = True

# %%
bool2 = False

# %%
print(type(bool1))
# Out:
# <class 'bool'>

# %%
print(type(bool2))
# Out:
# <class 'bool'>

# %%
bool(None)
# Out:
# False

# %% [markdown]
# Strings

# %%
str1 = "HELLO PYTHON" 
print(str1)
# Out:
# HELLO PYTHON

# %%
mystr = 'Hello World' # Define string using single quotes 
print(mystr)
# Out:
# Hello World

# %%
mystr = "Hello World" # Define string using double quotes 
print(mystr)
# Out:
# Hello World

# %%
mystr = """Hello 
World""" # Define string using triple quotes 
print(mystr)
# Out:
# Hello
# World

# %%
mystr = ('Happy ' 
'Monday ' 
'Everyone') 
print(mystr)
# Out:
# Happy Monday Everyone

# %% [markdown]
# string indexing

# %%
 
str1
# Out:
# 'HELLO PYTHON'

# %%
str1[0]
# Out:
# 'H'

# %%
 
str1[len(str1)-1]
# Out:
# 'N'

# %%
str1[5]
# Out:
# ' '

# %% [markdown]
# String Slicing

# %%
 
str1[0:5]
# Out:
# 'HELLO'

# %%
str1[6:12]
# Out:
# 'PYTHON'

# %%
str1[-4:]
# Out:
# 'THON'

# %%
str1[-6:]
# Out:
# 'PYTHON'

# %% [markdown]
# Update & Delete String

# %%
str1
# Out:
# 'HELLO PYTHON'
