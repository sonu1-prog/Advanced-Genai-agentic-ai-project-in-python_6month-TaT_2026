# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
feature_image=Image.open(r'C:\Users\sonali\OneDrive\Documents\Desktop\pic.jpg')

# %%
feature_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=664x1000>

# %%
print(type(feature_image))
print(type(image))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
fea_arr=np.asarray(feature_image)
fea_arr
# Out:
# array([[[ 9, 11,  8],
#         [ 9, 11,  8],
#         [ 9, 11,  8],
#         ...,
#         [31, 32, 26],
#         [31, 32, 26],
#         [31, 32, 26]],
#
#        [[ 9, 11,  8],
#         [ 9, 11,  8],
#         [ 9, 11,  8],
#         ...,
#         [31, 32, 27],
#         [31, 32, 27],
#         [31, 32, 27]],
#
#        [[10, 12,  9],
#         [10, 12,  9],
#         [10, 12,  9],
#         ...,
#         [30, 32, 27],
#         [30, 32, 27],
#         [30, 32, 27]],
#
#        ...,
#
#        [[27, 47, 38],
#         [29, 46, 36],
#         [29, 45, 35],
#         ...,
#         [32, 36, 22],
#         [39, 46, 30],
#         [48, 57, 38]],
#
#        [[26, 46, 37],
#         [27, 44, 34],
#         [28, 44, 34],
#         ...,
#         [25, 29, 15],
#         [37, 44, 28],
#         [37, 46, 27]],
#
#        [[25, 45, 36],
#         [26, 43, 33],
#         [27, 43, 33],
#         ...,
#         [22, 26, 12],
#         [34, 41, 25],
#         [25, 34, 15]]], shape=(1000, 664, 3), dtype=uint8)

# %%
plt.imshow(fea_arr)
plt.show()

# %%
fea_arr.shape
# Out:
# (1000, 664, 3)

# %%
my_arr=np.asarray(image)
my_arr
# Out:
# array([[[ 9, 11,  8],
#         [ 9, 11,  8],
#         [ 9, 11,  8],
#         ...,
#         [31, 32, 26],
#         [31, 32, 26],
#         [31, 32, 26]],
#
#        [[ 9, 11,  8],
#         [ 9, 11,  8],
#         [ 9, 11,  8],
#         ...,
#         [31, 32, 27],
#         [31, 32, 27],
#         [31, 32, 27]],
#
#        [[10, 12,  9],
#         [10, 12,  9],
#         [10, 12,  9],
#         ...,
#         [30, 32, 27],
#         [30, 32, 27],
#         [30, 32, 27]],
#
#        ...,
#
#        [[27, 47, 38],
#         [29, 46, 36],
#         [29, 45, 35],
#         ...,
#         [32, 36, 22],
#         [39, 46, 30],
#         [48, 57, 38]],
#
#        [[26, 46, 37],
#         [27, 44, 34],
#         [28, 44, 34],
#         ...,
#         [25, 29, 15],
#         [37, 44, 28],
#         [37, 46, 27]],
#
#        [[25, 45, 36],
#         [26, 43, 33],
#         [27, 43, 33],
#         ...,
#         [22, 26, 12],
#         [34, 41, 25],
#         [25, 34, 15]]], shape=(1000, 664, 3), dtype=uint8)
