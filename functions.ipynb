# %%
def greet():
    print('hello')

# %%
def greet():
    print('hello good morning')
greet()
# Out:
# hello good morning

# %%
def greet():
    print('hello good morning')
greet()
def greet():
    print('hello good morning')
greet()
def greet():
    print('hello good morning')
greet()
# Out:
# hello good morning
# hello good morning
# hello good morning

# %%
def greet():
    print('hello good morning')
greet()
greet()
greet()
# Out:
# hello good morning
# hello good morning
# hello good morning

# %%
def add(x,y):
    c=x+y
    print(c)
r= add(5,6)
print(r)
print(type(r))
# Out:
# 11
# None
# <class 'NoneType'>

# %%
def add(x,y):
    c=x+y
    return c
r=add(5,6)
print(r)
print(type(r))
# Out:
# 11
# <class 'int'>

# %%
def add(x,y):
    c=x+y
    return c
add(3,4,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2     c=x+y
#       3     return c
# ----> 4 add(3,4,5)
#
# TypeError: add() takes 2 positional arguments but 3 were given

# %%
def add(x,y,z):
    c=x+y+z
    return c
add(3,4,5)

# %%
def add(x,y,z):
    c=x+y+z
    return c
add(3,4)

# %%
def add(x,y):
    c=x+y
    return c
print(add(3,4))
def greet():
    return 'gello good morning'
print(greet())
# Out:
# 7
# gello good morning

# %%
def add(x, y): 
    c = x + y
    return c
    
def greet(): 
    return 'hello good morning'

r1 = add(3,4)
r2 = greet()

print(r1)
print(r2)

print(type(r1))
print(type(r2))
# Out:
# 7
# hello good morning
# <class 'int'>
# <class 'str'>

# %%
def add(x, y): 
    c = x + y
    print(c)
    
def greet(): 
    print('hello good morning')

r1 = add(3,4)
r2 = greet()

print(r1)
print(r2)

print(type(r1))
print(type(r2))
# Out:
# 7
# hello good morning
# None
# None
# <class 'NoneType'>
# <class 'NoneType'>

# %%
def greet():
    print('hello')
    print('good noon')
    
def add(x,y):
    c=x+y
    print(c)

def sub(x,y,z):
    d = x-y-z
    print(d)
    
greet()    
add(5,4)
sub(10,2,4)
# Out:
# hello
# good noon
# 9
# 4

# %%
def greet():
    print('hello')
     
def add_sub(x,y):
    c=x+y
    d=x-y
    print(c)
    print(d)
  
greet()    
add_sub(5,4)
# Out:
# hello
# 9
# 1

# %%
def greet():
    print('hello')
     
def add_sub(x,y):
    c=x+y
    d=x-y
    print(c)
    print(d)
  
r1 = greet()    
r2 = add_sub(5,4)

print(type(r1))
print(type(r2))
# Out:
# hello
# 9
# 1
# <class 'NoneType'>
# <class 'NoneType'>

# %%
def greet():
    return 'hello'
     
def add_sub(x,y):
    c=x+y
    d=x-y
    return c, d
  
r1 = greet()    
r2 = add_sub(5,4)

print(r1)
print(r2)

print(type(r1))
print(type(r2))
# Out:
# hello
# (9, 1)
# <class 'str'>
# <class 'tuple'>

# %%
def greet():
    return 'hello'
     
def add_sub(x,y):
    c=x+y
    d=x-y
    return c
    return d
  
r1 = greet()    
r2 = add_sub(5,4)

print(r1)
print(r2)

print(type(r1))
print(type(r2))
# Out:
# hello
# 9
# <class 'str'>
# <class 'int'>

# %%
def greet():
    return 'hello'
     
def add_sub(x,y):
    c=x+y
    d=x-y
    return c,d
  
r1 = greet()    
r2,r3 = add_sub(5,4)

print(r1)
print(r2)
print(r3)

print(type(r1))
print(type(r2))
print(type(r3))
# Out:
# hello
# 9
# 1
# <class 'str'>
# <class 'int'>
# <class 'int'>

# %%
def add(a,b):
    c=a+b
    print(c)
add(5,6)
# Out:
# 11

# %% [markdown]
# # 1- positional arguments

# %%
def person(name,age):
    print(name)
    print(age)
person('nit')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       2     print(name)
#       3     print(age)
# ----> 4 person('nit')
#
# TypeError: person() missing 1 required positional argument: 'age'

# %%
def person(name):
    print(name)
    print(age)
    
person('nit', 23)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 5
#       2     print(name)
#       3     print(age)
# ----> 5 person('nit', 23)
#
# TypeError: person() takes 1 positional argument but 2 were given

# %%
def person (name,age):
    print(name)
    print(age)
person('nit',23)
# Out:
# nit
# 23

# %%
def person(age,name):
    print(name)
    print(age)
person('nit',23)
# Out:
# 23
# nit

# %%
def person(age, name):
    print(name)
    print(age+1)
    
person('nit', 23)
# Out:
# 23
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 5
#       2     print(name)
#       3     print(age+1)
# ----> 5 person('nit', 23)
#
# Cell In[22], line 3, in person(age, name)
#       1 def person(age, name):
#       2     print(name)
# ----> 3     print(age+1)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # 2- keyword arguments

# %%
def person(age,name):
    print(name)
    print(age+1)
person('nit',23)
# Out:
# 23
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       2     print(name)
#       3     print(age+1)
# ----> 4 person('nit',23)
#
# Cell In[23], line 3, in person(age, name)
#       1 def person(age,name):
#       2     print(name)
# ----> 3     print(age+1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
def person(age, name):
    
    print(name)
    print(age+1)

person(name = 'nit', age = 23)
# Out:
# nit
# 24

# %%
def person(age, name, mob):
    print(name)
    print(age+1)
    print(mob)

person(name = 'nit', age = 23, 12345)
# Out:
#   Cell In[25], line 6
#     person(name = 'nit', age = 23, 12345)
#                                         ^
# SyntaxError: positional argument follows keyword argument

# %%
def person(age, name, mob):
    print(name)
    print(age+1)
    print(mob)

person(name = 'nit', age = 23, mob = 12345)
# Out:
# nit
# 24
# 12345

# %% [markdown]
# # default argument

# %%
def person(name,age):
    print(name)
    print(age)
person('nit')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       2     print(name)
#       3     print(age)
# ----> 4 person('nit')
#
# TypeError: person() missing 1 required positional argument: 'age'

# %%
def person(name,age=18):
    print(name)
    print(age)
person('nit')
# Out:
# nit
# 18

# %%
def person(name,age=20):
    print(name)
    print(age)
person('nit')
# Out:
# nit
# 20

# %% [markdown]
# # varaible length arguments

# %%
def sum(a,b):
    c=a+b
    print(c)
sum(5,6)
# Out:
# 11

# %%
def sum(a,b):
    c=a+b
    print(C)
sum(5,6,7,8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 4
#       2     c=a+b
#       3     print(C)
# ----> 4 sum(5,6,7,8)
#
# TypeError: sum() takes 2 positional arguments but 4 were given

# %%
def sum(a,b):
    c=a+b
    print(c)
sum(5,6,7,8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 4
#       2     c=a+b
#       3     print(c)
# ----> 4 sum(5,6,7,8)
#
# TypeError: sum() takes 2 positional arguments but 4 were given

# %%
def sum(a,*b):
    print(type(a))
    print(type(b))
    print(a)
    print(b)
sum(5,6,7,8)
# Out:
# <class 'int'>
# <class 'tuple'>
# 5
# (6, 7, 8)

# %%
def sum(a,*b):
    c=a
    for i in b:
        c=c+i
    print(c)
sum(5,6,7,8)
# Out:
# 26

# %%
def sum(a,*b):
    c=a
    for i in b:
        c=c+i
    print(c)
sum(5,6,7,8,9,10,-1,-2,100)
# Out:
# 142

# %% [markdown]
# # KWARGS (KW + ARGS)

# %%
def person():
    person('alex',36,'jhon',45)

# %%
def person(name,*data):
    print(name)
    print(data)

person('ALEX', 36, 'JOHN', 987767)
# Out:
# ALEX
# (36, 'JOHN', 987767)

# %%
def person(name,*data):
    print(name)
    print(data)

person('ALEX', 36, 'JOHN', 987767)
# Out:
# ALEX
# (36, 'JOHN', 987767)

# %%
def person(name, *data):
    print('name')
    print(data)

person('ALEX', age = 36, home_place ='southcity', mob =987767)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 5
#       2     print('name')
#       3     print(data)
# ----> 5 person('ALEX', age = 36, home_place ='southcity', mob =987767)
#
# TypeError: person() got an unexpected keyword argument 'age'

# %%
def person(name, **data):
    print('name')
    print(data)

person('ALEX', age = 36, home_place ='southcity', mob =987767)
# Out:
# name
# {'age': 36, 'home_place': 'southcity', 'mob': 987767}
