# %%
x=sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x=sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
round(math.sqrt(25))
# Out:
# 5

# %%
math.floor(4.9)
# Out:
# 4

# %%
math.ceil(4.9)
# Out:
# 5

# %%
pow(9,2)
# Out:
# 81

# %%
math.pi
# Out:
# 3.141592653589793

# %%
pi=3.17
pi
# Out:
# 3.17

# %%
math.sqrt(64)
# Out:
# 8.0

# %%
import math as m

# %%
m.sqrt(49)
# Out:
# 7.0

# %%
from math import sqrt,pow
print(pow(2,3))
print(m.sqrt(10))
# Out:
# 8.0
# 3.1622776601683795

# %%
print(math.e)
# Out:
# 2.718281828459045

# %% [markdown]
# ### input()

# %%
input()
# Out:
#  hello
# 'hello'

# %%
input()
input()
# Out:
#  hello
#  hi
# 'hi'

# %%
x=input()
y=input()
z=x+y
print(z)
# Out:
#  3
#  10
# 310

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
x=int(input())
y=int(input())
z=x+y
print(z)
# Out:
#  3
#  10
# 13

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x1=input('enter the 1st number')
y1=input('enter the 2nd number')
z1=x1+y1
print(z1)
# Out:
# enter the 1st number 20
# enter the 2nd number 30
# 2030

# %%
x1=int(input('enter the 1st number'))
y1=int(input('enter the 2nd number'))
z1=x1+y1
print(z1)
# Out:
# enter the 1st number 20
# enter the 2nd number 30
# 50

# %%
x2=input('enter user_name:')
y2=input('enter password:')
z2=x2+y2
print(z2)
# Out:
# enter user_name: tippana
# enter password: sonali
# tippanasonali

# %%
st=input('enter a string')[0]
print(st)
# Out:
# enter a string hello
# h

# %%
st=input('enter a string')[0:4]
print(st)
# Out:
# enter a string tippana
# tipp

# %%
st=input('enter a string')[6:9]
print(st)
# Out:
# enter a string tippanasonali
# aso
